# %%
# import pandas and matplotlib modules
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("alphabet_stock_data.csv")

# %%
data
# Out:
#            Date         Open         High          Low        Close  \
# 0    2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1    2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2    2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3    2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4    2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
# ..          ...          ...          ...          ...          ...
# 122  2020-09-24  1411.030029  1443.708984  1409.849976  1428.290039
# 123  2020-09-25  1432.630005  1450.000000  1413.339966  1444.959961
# 124  2020-09-28  1474.209961  1476.800049  1449.301025  1464.520020
# 125  2020-09-29  1470.390015  1476.662964  1458.805054  1469.329956
# 126  2020-09-30  1466.800049  1489.750000  1459.880005  1469.599976
#
#        Adj Close   Volume
# 0    1105.619995  2343100
# 1    1120.839966  1964900
# 2    1097.880005  2313400
# 3    1186.920044  2664700
# ...

# %%
start_date = pd.to_datetime('2020-05-01')
end_date = pd.to_datetime('2020-09-19')
data['Date'] = pd.to_datetime(data['Date'])

# %%
within_span = (data['Date'] >= start_date) & (data['Date'] <= end_date)

# %%
fix = data[within_span]

# %%
fix
# Out:
#           Date         Open         High          Low        Close  \
# 21  2020-05-01  1328.500000  1352.069946  1311.000000  1320.609985
# 22  2020-05-04  1308.229980  1327.660034  1299.000000  1326.800049
# 23  2020-05-05  1337.920044  1373.939941  1337.459961  1351.109985
# 24  2020-05-06  1361.689941  1371.119995  1347.290039  1347.300049
# 25  2020-05-07  1365.939941  1377.599976  1355.270020  1372.560059
# ..         ...          ...          ...          ...          ...
# 114 2020-09-14  1539.005005  1564.000000  1515.739990  1519.280029
# 115 2020-09-15  1536.000000  1559.569946  1531.834961  1541.439941
# 116 2020-09-16  1555.540039  1562.000000  1519.819946  1520.900024
# 117 2020-09-17  1496.000000  1508.297974  1470.000000  1495.530029
# 118 2020-09-18  1498.010010  1503.003052  1437.130005  1459.989990
#
#        Adj Close   Volume
# 21   1320.609985  2072500
# 22   1326.800049  1504000
# 23   1351.109985  1651500
# 24   1347.300049  1215400
# ...

# %%
fix_index = fix.set_index('Date')
fix_index
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-05-01  1328.500000  1352.069946  1311.000000  1320.609985  1320.609985
# 2020-05-04  1308.229980  1327.660034  1299.000000  1326.800049  1326.800049
# 2020-05-05  1337.920044  1373.939941  1337.459961  1351.109985  1351.109985
# 2020-05-06  1361.689941  1371.119995  1347.290039  1347.300049  1347.300049
# 2020-05-07  1365.939941  1377.599976  1355.270020  1372.560059  1372.560059
# ...                 ...          ...          ...          ...          ...
# 2020-09-14  1539.005005  1564.000000  1515.739990  1519.280029  1519.280029
# 2020-09-15  1536.000000  1559.569946  1531.834961  1541.439941  1541.439941
# 2020-09-16  1555.540039  1562.000000  1519.819946  1520.900024  1520.900024
# 2020-09-17  1496.000000  1508.297974  1470.000000  1495.530029  1495.530029
# 2020-09-18  1498.010010  1503.003052  1437.130005  1459.989990  1459.989990
#
#              Volume
# Date
# 2020-05-01  2072500
# ...

# %%
plt.figure(figsize=(10,10))
fix_index['Close'].plot(color='red')
plt.title('Stock Prices of Alphabet Inc.')
plt.xlabel('Date')
plt.ylabel('$ Price')
# Out:
# Text(0, 0.5, '$ Price')
